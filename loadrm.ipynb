# %%
import numpy as np

# %%
ld=np.genfromtxt('/Users/gracekim/flying_focus/FF_rays/dz-5e-07_k--0.50_eps-1.0e-07_lr-1.0e-02_No-20_Nr-20_N-10/dz-5e-07_k--0.50_eps-1.0e-07_lr-1.0e-02_No-20_Nr-20_N-10_rm.csv')

# %%
ld.reshape(ld.shape[0],ld.shape[1]//4,4)
# Out:
# array([[[ 0.00000000e+00, -4.25221155e-05,  0.00000000e+00,
#           5.62500000e-02],
#         [ 1.97368421e-03, -9.56404607e-06,  1.78136855e-05,
#           5.62500000e-02],
#         [ 3.94736842e-03,  1.19835795e-06,  6.97627383e-05,
#           5.62500000e-02],
#         [ 5.92105263e-03, -4.69034841e-06,  1.56371165e-04,
#           5.62500000e-02],
#         [ 7.89473684e-03, -9.72366705e-06,  2.77679040e-04,
#           5.62500000e-02],
#         [ 9.86842105e-03, -1.91561655e-05,  4.33742594e-04,
#           5.62500000e-02],
#         [ 1.18421053e-02, -3.33739235e-05,  6.24634351e-04,
#           5.62500000e-02],
#         [ 1.38157895e-02, -5.34572397e-05,  8.50443291e-04,
#           5.62500000e-02],
#         [ 1.57894737e-02, -8.05578344e-05,  1.11127507e-03,
#           5.62500000e-02],
#         [ 1.77631579e-02, -1.15914464e-04,  1.40725224e-03,
#           5.62500000e-02],
#         [ 1.97368421e-02, -1.60870486e-04,  1.73851459e-03,
# ...
