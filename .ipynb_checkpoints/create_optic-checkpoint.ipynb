# %%
import numpy as np
import time
from scipy.interpolate import CubicSpline
import matplotlib.pyplot as plt
font = {'family' : 'normal',
        'size'   : 28}

plt.rc('font', **font)

# %%
def create_starting_optic(thick,R,k=-1,N=100):
    z=np.linspace(0,thick,N) #solves the problem of not having enough points close to the origin
    r=np.sqrt(2*R*z-(k+1)*z**2) 
    optic=np.array([z,r])
    return optic

# %%
start_o = create_starting_optic(0.0064,0.1125,k=-0.8,N=100)
sor=start_o[1]

# %%
soz=np.copy(start_o[0])
signs=np.random.choice([-1,1],99)
dz=signs*1e-4
soz[1:]+=dz
print(soz)
# Out:
# [ 0.00000000e+00 -3.53535354e-05  2.92929293e-05  2.93939394e-04
#   3.58585859e-04  4.23232323e-04  2.87878788e-04  3.52525253e-04
#   6.17171717e-04  6.81818182e-04  5.46464646e-04  6.11111111e-04
#   8.75757576e-04  7.40404040e-04  8.05050505e-04  8.69696970e-04
#   9.34343434e-04  1.19898990e-03  1.26363636e-03  1.12828283e-03
#   1.39292929e-03  1.25757576e-03  1.32222222e-03  1.58686869e-03
#   1.45151515e-03  1.71616162e-03  1.78080808e-03  1.64545455e-03
#   1.91010101e-03  1.77474747e-03  2.03939394e-03  2.10404040e-03
#   2.16868687e-03  2.23333333e-03  2.29797980e-03  2.16262626e-03
#   2.42727273e-03  2.29191919e-03  2.35656566e-03  2.42121212e-03
#   2.48585859e-03  2.55050505e-03  2.81515152e-03  2.87979798e-03
#   2.94444444e-03  2.80909091e-03  3.07373737e-03  2.93838384e-03
#   3.20303030e-03  3.06767677e-03  3.13232323e-03  3.19696970e-03
#   3.26161616e-03  3.32626263e-03  3.59090909e-03  3.45555556e-03
#   3.72020202e-03  3.78484848e-03  3.84949495e-03  3.71414141e-03
#   3.77878788e-03  4.04343434e-03  4.10808081e-03  4.17272727e-03
#   4.23737374e-03  4.10202020e-03  4.16666667e-03  4.43131313e-03
#   4.49595960e-03  4.36060606e-03  4.42525253e-03  4.48989899e-03
#   4.55454545e-03  4.81919192e-03  4.88383838e-03  4.74848485e-03
#   4.81313131e-03  4.87777778e-03  5.14242424e-03  5.20707071e-03
#   5.27171717e-03  5.33636364e-03  5.20101010e-03  5.26565657e-03
#   5.33030303e-03  5.39494949e-03  5.65959596e-03  5.72424242e-03
#   5.58888889e-03  5.85353535e-03  5.71818182e-03  5.98282828e-03
#   5.84747475e-03  6.11212121e-03  5.97676768e-03  6.04141414e-03
#   6.10606061e-03  6.17070707e-03  6.23535354e-03  6.30000000e-03]

# %%
plt.figure(figsize=(10,20))
plt.scatter(start_o[0],start_o[1],c='b',label='starting optic')
plt.scatter(start_o[0],-1*start_o[1],c='b')

plt.scatter(soz,start_o[1],c='r',label='step 1')
plt.scatter(soz,-1*start_o[1],c='r')
plt.xlabel('z(m)')
plt.ylabel('r(m)')
plt.legend()
plt.savefig('step_1')
plt.show()
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
k08 = create_starting_optic(0.0064,0.1125,k=-0.8,N=100)
k1= create_starting_optic(0.0064,0.1125,k=-1,N=100)

plt.figure(figsize=(10,20))
plt.scatter(k08[0],k08[1],c='b',label='k=-0.8')
plt.scatter(k08[0],-1*k08[1],c='b')

plt.scatter(k1[0],k1[1],c='r',label='k=-1')
plt.scatter(k1[0],-1*k1[1],c='r')
plt.xlabel('z(m)')
plt.ylabel('r(m)')
plt.legend()
plt.savefig('step_1')
plt.show()

# %%
0.075/2
# Out:
# 0.0375

# %%
r=np.linspace(0,0.0375,100)
z08=r**2/(0.1125*(1+np.sqrt(1-(1-0.8)*r**2)))
z1=r**2/(0.1125*(1+np.sqrt(1-(1-1)*r**2)))
plt.figure(figsize=(10,20))
plt.plot(k08[0],k08[1],label='create_starting_optic')
plt.plot(z08,r,label='switched')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,20))
plt.scatter(z08,r,label='k=-0.8')
plt.scatter(z1,r,label='k=-1')

plt.xlabel('z(m)')
plt.ylabel('r(m)')
plt.legend()
plt.show()

# %%
len(z1)
# Out:
# 100

# %%
z1-z08
# Out:
# array([ 0.00000000e+00, -4.57479657e-15, -7.31967477e-14, -3.70558563e-13,
#        -1.17114817e-12, -2.85924883e-12, -5.92893931e-12, -1.09840941e-11,
#        -1.87383836e-11, -3.00152746e-11, -4.57480305e-11, -6.69797116e-11,
#        -9.48631759e-11, -1.30661079e-10, -1.75745876e-10, -2.31599820e-10,
#        -2.99814964e-10, -3.82093162e-10, -4.80246068e-10, -5.96195141e-10,
#        -7.31971639e-10, -8.89716625e-10, -1.07168097e-09, -1.28022534e-09,
#        -1.51782022e-09, -1.78704590e-09, -2.09059248e-09, -2.43125985e-09,
#        -2.81195774e-09, -3.23570568e-09, -3.70563300e-09, -4.22497888e-09,
#        -4.79709228e-09, -5.42543199e-09, -6.11356664e-09, -6.86517464e-09,
#        -7.68404426e-09, -8.57407357e-09, -9.53927048e-09, -1.05837527e-08,
#        -1.17117479e-08, -1.29275933e-08, -1.42357362e-08, -1.56407337e-08,
#        -1.71472527e-08, -1.87600699e-08, -2.04840719e-08, -2.23242551e-08,
#        -2.42857257e-08, -2.63736999e-08, -2.85935037e-08, -3.09505728e-08,
#        -3.34504530e-08, -3.60987997e-08, -3.89013783e-08, -4.18640641e-08,
#        -4.49928422e-08, -4.82938076e-08, -5.17731651e-08, -5.54372294e-08,
#        -5.92924251e-08, -6.33452867e-08, -6.76024586e-08, -7.20706949e-08,
#        -7.67568598e-08, -8.16679273e-08, -8.68109813e-08, -9.21932156e-08,
#        -9.78219339e-08, -1.03704550e-07, -1.09848587e-07, -1.16261678e-07,
#        -1.22951567e-07, -1.29926108e-07, -1.37193262e-07, -1.44761104e-07,
#        -1.52637815e-07, -1.60831691e-07, -1.69351132e-07, -1.78204652e-07,
#        -1.87400873e-07, -1.96948529e-07, -2.06856461e-07, -2.17133623e-07,
#        -2.27789077e-07, -2.38831995e-07, -2.50271660e-07, -2.62117464e-07,
#        -2.74378910e-07, -2.87065610e-07, -3.00187286e-07, -3.13753771e-07,
#        -3.27775006e-07, -3.42261045e-07, -3.57222050e-07, -3.72668292e-07,
#        -3.88610154e-07, -4.05058128e-07, -4.22022818e-07, -4.39514934e-07])

# %%
plt.plot(r,z1-z08)
plt.show()
